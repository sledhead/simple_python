# %% [markdown]
# <a href="https://colab.research.google.com/github/sledhead/simple_python/blob/main/pandas_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
#Will display upload box to user to allow a file to upload and encrypted.
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !wget https://github.com/chris1610/pbpython/raw/master/data/sales_9_2022.xlsx
# Out:
# --2024-04-16 07:12:42--  https://github.com/chris1610/pbpython/raw/master/data/sales_9_2022.xlsx
# Resolving github.com (github.com)... 140.82.114.3
# Connecting to github.com (github.com)|140.82.114.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/chris1610/pbpython/master/data/sales_9_2022.xlsx [following]
# --2024-04-16 07:12:43--  https://raw.githubusercontent.com/chris1610/pbpython/master/data/sales_9_2022.xlsx
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.108.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 10186 (9.9K) [application/octet-stream]
# Saving to: ‘sales_9_2022.xlsx’
#
# sales_9_2022.xlsx   100%[===================>]   9.95K  --.-KB/s    in 0s
#
# ...

# %%
df = pd.read_excel('sales_9_2022.xlsx')
df["Sales"].sum()

df.groupby(['Region']).agg({'Sales': 'sum'})
# Out:
#           Sales
# Region
# APAC    1255000
# EMEA    1561000
# US      5184000

# %%
print(df.columns)
# Out:
# Index(['Customer ID', 'Customer Name', 'Region', 'Segment', 'Sales'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Customer ID    20 non-null     int64
#  1   Customer Name  20 non-null     object
#  2   Region         20 non-null     object
#  3   Segment        16 non-null     object
#  4   Sales          20 non-null     int64
# dtypes: int64(2), object(3)
# memory usage: 928.0+ bytes

# %%
print(type(df.columns))
col_list = list(df.columns)
# Out:
# <class 'pandas.core.indexes.base.Index'>

# %%
print(col_list)
# Out:
# ['Customer ID', 'Customer Name', 'Region', 'Segment', 'Sales']

# %%
df.groupby(['Region', 'Segment']).agg({'Sales': 'sum'})
# Out:
#                    Sales
# Region Segment
# APAC   Gold       215000
#        Platinum   630000
#        Silver     410000
# EMEA   Gold       630000
#        Platinum   410000
#        Silver     430000
# US     Gold      1479000
#        Platinum  1555000
#        Silver    1260000

# %%
df.groupby(['Region', 'Segment']).agg({'Sales': 'sum'}).sum()
# Out:
# Sales    7019000
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Customer ID      0
# Customer Name    0
# Region           0
# Segment          4
# Sales            0
# dtype: int64

# %%
df.fillna('unknown').groupby(['Region', 'Segment']).agg({'Sales': 'sum'})
# Out:
#                    Sales
# Region Segment
# APAC   Gold       215000
#        Platinum   630000
#        Silver     410000
# EMEA   Gold       630000
#        Platinum   410000
#        Silver     430000
#        unknown     91000
# US     Gold      1479000
#        Platinum  1555000
#        Silver    1260000
#        unknown    890000

# %%
# !wget https://github.com/AlexTheAnalyst/Excel-Tutorial/raw/main/Excel%20Project%20Dataset.xlsx
# Out:
# --2024-04-16 07:30:24--  https://github.com/AlexTheAnalyst/Excel-Tutorial/raw/main/Excel%20Project%20Dataset.xlsx
# Resolving github.com (github.com)... 140.82.113.4
# Connecting to github.com (github.com)|140.82.113.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/AlexTheAnalyst/Excel-Tutorial/main/Excel%20Project%20Dataset.xlsx [following]
# --2024-04-16 07:30:24--  https://raw.githubusercontent.com/AlexTheAnalyst/Excel-Tutorial/main/Excel%20Project%20Dataset.xlsx
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 73427 (72K) [application/octet-stream]
# Saving to: ‘Excel Project Dataset.xlsx’
#
# Excel Project Datas 100%[===================>]  71.71K  --.-KB/s    in 0.01s
#
# ...

# %%
df = pd.read_excel('Excel_Project_Dataset.xlsx')

df.head(10)
# Out:
#       ID Marital Status Gender  Income  Children            Education  \
# 0  12496              M      F   40000         1            Bachelors
# 1  24107              M      M   30000         3      Partial College
# 2  14177              M      M   80000         5      Partial College
# 3  24381              S      M   70000         0            Bachelors
# 4  25597              S      M   30000         0            Bachelors
# 5  13507              M      F   10000         2      Partial College
# 6  27974              S      M  160000         2          High School
# 7  19364              M      M   40000         1            Bachelors
# 8  22155              M      M   20000         2  Partial High School
# 9  19280              M      M  120000         2      Partial College
#
#        Occupation Home Owner  Cars Commute Distance   Region  Age  \
# 0  Skilled Manual        Yes     0        0-1 Miles   Europe   42
# ...

# %%
df['Children'].agg(['mean','min','max'])
# Out:
# mean    1.892788
# min     0.000000
# max     5.000000
# Name: Children, dtype: float64

# %%
df['Age'].agg(['mean','min','max'])
# Out:
# mean    44.138402
# min     25.000000
# max     89.000000
# Name: Age, dtype: float64

# %%
df['Income'].agg(['mean','min','max'])
# Out:
# mean     56208.576998
# min      10000.000000
# max     170000.000000
# Name: Income, dtype: float64

# %%
df.groupby(['Occupation']).agg({'Income':['mean','min','max']}).round(2)
# Out:
#                   Income
#                     mean    min     max
# Occupation
# Clerical        31229.95  10000   40000
# Management      86609.20  40000  170000
# Manual          17460.32  10000  120000
# Professional    75571.43  40000  170000
# Skilled Manual  51737.45  10000   90000

# %%
agg_func_describe = {'Income': ['describe']}
df.groupby(['Occupation']).agg(agg_func_describe).round(2)
# Out:
#                  Income                                                 \
#                describe
#                   count      mean       std      min      25%      50%
# Occupation
# Clerical          187.0  31229.95   7696.22  10000.0  30000.0  30000.0
# Management        174.0  86609.20  28416.74  40000.0  70000.0  80000.0
# Manual            126.0  17460.32  15946.74  10000.0  10000.0  10000.0
# Professional      280.0  75571.43  24779.21  40000.0  60000.0  70000.0
# Skilled Manual    259.0  51737.45  16834.60  10000.0  40000.0  50000.0
#
#
#
#                      75%       max
# Occupation
# Clerical         40000.0   40000.0
# Management      110000.0  170000.0
# Manual           20000.0  120000.0
# Professional     80000.0  170000.0
# Skilled Manual   60000.0   90000.0

# %%
agg_func_describe = {'Age': ['describe']}
df.groupby(['Occupation']).agg(agg_func_describe).round(2)
# Out:
#                     Age
#                describe
#                   count   mean    std   min   25%   50%    75%   max
# Occupation
# Clerical          187.0  42.83  12.39  25.0  33.5  39.0  50.00  80.0
# Management        174.0  53.34  11.87  31.0  42.0  56.0  63.75  78.0
# Manual            126.0  38.12   9.02  25.0  32.0  36.5  43.00  65.0
# Professional      280.0  45.17   8.75  29.0  38.0  45.0  51.00  73.0
# Skilled Manual    259.0  40.71   9.76  25.0  32.0  41.0  47.00  89.0

# %%
agg_func_count = {'Age': ['count', 'nunique', 'size']}
df.groupby(['Occupation']).agg(agg_func_count)
# Out:
#                  Age
#                count nunique size
# Occupation
# Clerical         187      43  187
# Management       174      41  174
# Manual           126      32  126
# Professional     280      37  280
# Skilled Manual   259      38  259

# %%
df.head(10)
# Out:
#       ID Marital Status Gender  Income  Children            Education  \
# 0  12496              M      F   40000         1            Bachelors
# 1  24107              M      M   30000         3      Partial College
# 2  14177              M      M   80000         5      Partial College
# 3  24381              S      M   70000         0            Bachelors
# 4  25597              S      M   30000         0            Bachelors
# 5  13507              M      F   10000         2      Partial College
# 6  27974              S      M  160000         2          High School
# 7  19364              M      M   40000         1            Bachelors
# 8  22155              M      M   20000         2  Partial High School
# 9  19280              M      M  120000         2      Partial College
#
#        Occupation Home Owner  Cars Commute Distance   Region  Age  \
# 0  Skilled Manual        Yes     0        0-1 Miles   Europe   42
# ...

# %%
df.loc[df.groupby('Occupation')['Age'].idxmax()]
# Out:
#         ID Marital Status Gender  Income  Children        Education  \
# 401  11555              M      F   40000         1        Bachelors
# 250  22931              M      M  100000         5  Graduate Degree
# 457  12236              M      F   20000         1  Partial College
# 553  17533              M      M   40000         3  Partial College
# 375  15628              M      F   40000         1        Bachelors
#
#          Occupation Home Owner  Cars Commute Distance         Region  Age  \
# 401        Clerical        Yes     0        0-1 Miles         Europe   80
# 250      Management         No     1        1-2 Miles        Pacific   78
# 457          Manual        Yes     0        0-1 Miles         Europe   65
# 553    Professional         No     2       5-10 Miles  North America   73
# 375  Skilled Manual        Yes     1        0-1 Miles         Europe   89
#
#     Purchased Bike
# 401             No
# 250            Yes
# 457             No
# 553            Yes
# ...

# %%
df.loc[df.groupby('Education')['Age'].idxmax()]
# Out:
#         ID Marital Status Gender  Income  Children            Education  \
# 375  15628              M      F   40000         1            Bachelors
# 250  22931              M      M  100000         5      Graduate Degree
# 595  18058              S      F   20000         3          High School
# 553  17533              M      M   40000         3      Partial College
# 868  24955              S      M   30000         5  Partial High School
#
#          Occupation Home Owner  Cars Commute Distance         Region  Age  \
# 375  Skilled Manual        Yes     1        0-1 Miles         Europe   89
# 250      Management         No     1        1-2 Miles        Pacific   78
# 595  Skilled Manual        Yes     2        2-5 Miles  North America   78
# 553    Professional         No     2       5-10 Miles  North America   73
# 868  Skilled Manual        Yes     3        10+ Miles  North America   60
#
#     Purchased Bike
# 375             No
# 250            Yes
# 595             No
# ...

# %%
agg_func_count = {'Age': ['count', 'nunique', 'size']}
df.groupby(['Education', 'Marital Status']).agg(agg_func_count)
# Out:
#                                      Age
#                                    count nunique size
# Education           Marital Status
# Bachelors           M                167      37  167
#                     S                144      35  144
# Graduate Degree     M                106      30  106
#                     S                 69      24   69
# High School         M                 98      34   98
#                     S                 86      33   86
# Partial College     M                148      38  148
#                     S                130      32  130
# Partial High School M                 30      15   30
#                     S                 48      22   48

# %%
agg_func_count = {'Income': ['mean', 'max', 'min']}
df.groupby(['Education', 'Marital Status']).agg(agg_func_count).round(2)
# Out:
#                                       Income
#                                         mean     max    min
# Education           Marital Status
# Bachelors           M               59401.20  150000  10000
#                     S               67291.67  130000  10000
# Graduate Degree     M               63962.26  130000  10000
#                     S               68985.51  170000  10000
# High School         M               53367.35  150000  10000
#                     S               40116.28  160000  10000
# Partial College     M               60878.38  170000  10000
#                     S               47461.54  150000  10000
# Partial High School M               42333.33  120000  10000
#                     S               28958.33  120000  10000

# %%
#https://engineering.purdue.edu/~dbuckmas/outreach/Machine_capacity.xlsx?_ga=2.131294031.1981894360.1712984914-603738501.1712984913
# !wget https://www.ers.usda.gov/webdocs/DataFiles/106595/Apples%202020.xlsx?v=1617.2
# Out:
# --2024-04-13 05:21:44--  https://www.ers.usda.gov/webdocs/DataFiles/106595/Apples%202020.xlsx?v=1617.2
# Resolving www.ers.usda.gov (www.ers.usda.gov)... 20.141.137.224
# Connecting to www.ers.usda.gov (www.ers.usda.gov)|20.141.137.224|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 13074 (13K) [application/vnd.openxmlformats-officedocument.spreadsheetml.sheet]
# Saving to: ‘Apples 2020.xlsx?v=1617.2’
#
# Apples 2020.xlsx?v= 100%[===================>]  12.77K  --.-KB/s    in 0s
#
# 2024-04-13 05:21:44 (159 MB/s) - ‘Apples 2020.xlsx?v=1617.2’ saved [13074/13074]

# %%
agg_func_count = {'Age': ['count', 'nunique', 'size']}
df.groupby(['Education', 'Purchased Bike']).agg(agg_func_count).round(2)
# Out:
#                                      Age
#                                    count nunique size
# Education           Purchased Bike
# Bachelors           No               142      35  142
#                     Yes              169      35  169
# Graduate Degree     No                80      29   80
#                     Yes               95      28   95
# High School         No               102      33  102
#                     Yes               82      33   82
# Partial College     No               151      39  151
#                     Yes              127      36  127
# Partial High School No                56      24   56
#                     Yes               22      13   22

# %%
agg_func_count = {'Income': ['sum']}
df_sp = df.groupby(['Education', 'Occupation']).agg(agg_func_count).assign(per_tot= lambda x : x / x.sum()).round(5)

# %%
df_sp.iloc[5]
# Out:
# Income   sum    810000.000
# per_tot              0.014
# Name: (Graduate Degree, Clerical), dtype: float64

# %%
df_sp
# Out:
#                                      Income  per_tot
#                                         sum
# Education           Occupation
# Bachelors           Clerical        1510000  0.02618
#                     Management      7970000  0.13820
#                     Manual            20000  0.00035
#                     Professional    6710000  0.11635
#                     Skilled Manual  3400000  0.05896
# Graduate Degree     Clerical         810000  0.01405
#                     Management      5220000  0.09051
#                     Manual            60000  0.00104
#                     Professional    3020000  0.05237
#                     Skilled Manual  2430000  0.04214
# High School         Clerical         120000  0.00208
#                     Management      1340000  0.02324
#                     Manual           910000  0.01578
#                     Professional    3890000  0.06745
#                     Skilled Manual  2420000  0.04196
# ...

# %%
df_new = df_sp.assign(Per = df_sp.per_tot * 100)

# %%
df_new
# Out:
#                                      Income  per_tot     Per
#                                         sum
# Education           Occupation
# Bachelors           Clerical        1510000  0.02618   2.618
#                     Management      7970000  0.13820  13.820
#                     Manual            20000  0.00035   0.035
#                     Professional    6710000  0.11635  11.635
#                     Skilled Manual  3400000  0.05896   5.896
# Graduate Degree     Clerical         810000  0.01405   1.405
#                     Management      5220000  0.09051   9.051
#                     Manual            60000  0.00104   0.104
#                     Professional    3020000  0.05237   5.237
#                     Skilled Manual  2430000  0.04214   4.214
# High School         Clerical         120000  0.00208   0.208
#                     Management      1340000  0.02324   2.324
#                     Manual           910000  0.01578   1.578
# ...

# %%
agg_func_count = {'Income': ['sum']}
df_sp = df.groupby(['Education', 'Gender']).agg(agg_func_count).assign(per_tot= lambda x : x / x.sum()).round(5)

# %%
df_sp
# Out:
#                              Income  per_tot
#                                 sum
# Education           Gender
# Bachelors           F       9640000  0.16716
#                     M       9970000  0.17288
# Graduate Degree     F       5950000  0.10317
#                     M       5590000  0.09693
# High School         F       3700000  0.06416
#                     M       4980000  0.08635
# Partial College     F       6780000  0.11757
#                     M       8400000  0.14566
# Partial High School F       1150000  0.01994
#                     M       1510000  0.02618

# %%
df_new = df_sp.assign(Per = df_sp.per_tot * 100)

# %%
df_new
# Out:
#                              Income  per_tot     Per
#                                 sum
# Education           Gender
# Bachelors           F       9640000  0.16716  16.716
#                     M       9970000  0.17288  17.288
# Graduate Degree     F       5950000  0.10317  10.317
#                     M       5590000  0.09693   9.693
# High School         F       3700000  0.06416   6.416
#                     M       4980000  0.08635   8.635
# Partial College     F       6780000  0.11757  11.757
#                     M       8400000  0.14566  14.566
# Partial High School F       1150000  0.01994   1.994
#                     M       1510000  0.02618   2.618
