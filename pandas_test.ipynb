# %% [markdown]
# <a href="https://colab.research.google.com/github/sledhead/simple_python/blob/main/pandas_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
#Will display upload box to user to allow a file to upload and encrypted.
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !wget https://github.com/chris1610/pbpython/raw/master/data/sales_9_2022.xlsx
# Out:
# --2024-04-13 00:31:55--  https://github.com/chris1610/pbpython/raw/master/data/sales_9_2022.xlsx
# Resolving github.com (github.com)... 140.82.114.3
# Connecting to github.com (github.com)|140.82.114.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/chris1610/pbpython/master/data/sales_9_2022.xlsx [following]
# --2024-04-13 00:31:55--  https://raw.githubusercontent.com/chris1610/pbpython/master/data/sales_9_2022.xlsx
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 10186 (9.9K) [application/octet-stream]
# Saving to: ‘sales_9_2022.xlsx’
#
# sales_9_2022.xlsx   100%[===================>]   9.95K  --.-KB/s    in 0s
#
# ...

# %%
df = pd.read_excel('sales_9_2022.xlsx')
df["Sales"].sum()

df.groupby(['Region']).agg({'Sales': 'sum'})
# Out:
#           Sales
# Region
# APAC    1255000
# EMEA    1561000
# US      5184000

# %%
df.groupby(['Region', 'Segment']).agg({'Sales': 'sum'})
# Out:
#                    Sales
# Region Segment
# APAC   Gold       215000
#        Platinum   630000
#        Silver     410000
# EMEA   Gold       630000
#        Platinum   410000
#        Silver     430000
# US     Gold      1479000
#        Platinum  1555000
#        Silver    1260000

# %%
df.groupby(['Region', 'Segment']).agg({'Sales': 'sum'}).sum()
# Out:
# Sales    7019000
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Customer ID      0
# Customer Name    0
# Region           0
# Segment          4
# Sales            0
# dtype: int64

# %%
df.fillna('unknown').groupby(['Region', 'Segment']).agg({'Sales': 'sum'})
# Out:
#                    Sales
# Region Segment
# APAC   Gold       215000
#        Platinum   630000
#        Silver     410000
# EMEA   Gold       630000
#        Platinum   410000
#        Silver     430000
#        unknown     91000
# US     Gold      1479000
#        Platinum  1555000
#        Silver    1260000
#        unknown    890000
